# %%
##hahahaha

# %%
#bat file
#d:
#cd d:\dan
#python -m venv d:\dan\venv2
#.\venv2\scripts\activate.bat
#pip install tensorflow
#pip install numpy scipy matplotlib ipython jupyter pandas sympy nose
#pip install sklearn
#pip install plotly
#jupyter notebook

# %%
# %reset -f
import numpy as np, tensorflow, plotly.express, matplotlib.pyplot as plt
N=1000
x=np.arange(N)/N
y=x+np.random.rand(N)*0.2+np.sqrt(x)+np.minimum(x,0.4)

plt.plot(x,y)
plt.show()

# %%
plotly.express.scatter(x,y)
# Out:
# <div>                            <div id="7364d88d-3643-4816-af27-d59482c1ce41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7364d88d-3643-4816-af27-d59482c1ce41")) {                    Plotly.newPlot(                        "7364d88d-3643-4816-af27-d59482c1ce41",                        [{"hovertemplate":"x=%{x}<br>index=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[0.1435824213413369,0.23007109302681272,0.24279223491014645,0.1841160769606532,0.08048152612513733,0.17917658996205826,0.1132970620883523,0.1037463530595226,0.26932795302940415,0.23177429994891285,0.1711107413763704,0.25839231644980426,0.15217772151825776,0.3146784888989461,0.259
# ...
